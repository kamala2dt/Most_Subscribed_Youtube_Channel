# %% [markdown]
# <a href="https://colab.research.google.com/github/kamala2dt/Most_Subscribed_Youtube_Channel/blob/main/Most_Subscribed_Youtube_Channel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Import Libraries**

# %%
# data
import pandas as pd
import numpy as np

# visualization
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **2. Read Dataset**

# %%
df = pd.read_csv("topSubscribed.csv")
df.head()
# Out:
#    Rank             Youtube Channel  Subscribers      Video Views Video Count  \
# 0     1                    T-Series  234,000,000  212,900,271,553      18,515
# 1     2              YouTube Movies  161,000,000                0           0
# 2     3  Cocomelon - Nursery Rhymes  152,000,000  149,084,178,448         846
# 3     4                   SET India  150,000,000  137,828,094,104     103,200
# 4     5                     MrBeast  128,000,000   21,549,128,785         733
#
#            Category  Started
# 0             Music     2006
# 1  Film & Animation     2015
# 2         Education     2006
# 3             Shows     2006
# 4     Entertainment     2012

# %% [markdown]
# **3. Data Processing**

# %%
df.shape
# Out:
# (1000, 7)

# %%
df.dtypes
# Out:
# Rank                int64
# Youtube Channel    object
# Subscribers        object
# Video Views        object
# Video Count        object
# Category           object
# Started             int64
# dtype: object

# %% [markdown]
# *Found the columns of Subscribers, Video Views and Video Count have string data types , So I will change to integer data types.*

# %%
df["Subscribers"] = df["Subscribers"].str.replace(",","").astype(int)
df["Video Views"] = df["Video Views"].str.replace(",","").astype(int)
df["Video Count"] = df["Video Count"].str.replace(",","").astype(int)

df.head()
# Out:
#    Rank             Youtube Channel  Subscribers   Video Views  Video Count  \
# 0     1                    T-Series    234000000  212900271553        18515
# 1     2              YouTube Movies    161000000             0            0
# 2     3  Cocomelon - Nursery Rhymes    152000000  149084178448          846
# 3     4                   SET India    150000000  137828094104       103200
# 4     5                     MrBeast    128000000   21549128785          733
#
#            Category  Started
# 0             Music     2006
# 1  Film & Animation     2015
# 2         Education     2006
# 3             Shows     2006
# 4     Entertainment     2012

# %%
df.dtypes
# Out:
# Rank                int64
# Youtube Channel    object
# Subscribers         int64
# Video Views         int64
# Video Count         int64
# Category           object
# Started             int64
# dtype: object

# %% [markdown]
# *Delete some column that not related.*

# %%
df = df.drop(["Rank"], axis = 1 )
df.head()
# Out:
#               Youtube Channel  Subscribers   Video Views  Video Count  \
# 0                    T-Series    234000000  212900271553        18515
# 1              YouTube Movies    161000000             0            0
# 2  Cocomelon - Nursery Rhymes    152000000  149084178448          846
# 3                   SET India    150000000  137828094104       103200
# 4                     MrBeast    128000000   21549128785          733
#
#            Category  Started
# 0             Music     2006
# 1  Film & Animation     2015
# 2         Education     2006
# 3             Shows     2006
# 4     Entertainment     2012

# %% [markdown]
# *Check missing values.*

# %%
df.isnull().sum()
# Out:
# Youtube Channel    0
# Subscribers        0
# Video Views        0
# Video Count        0
# Category           0
# Started            0
# dtype: int64

# %%
df.Category.unique()
# Out:
# array(['Music', 'Film & Animation', 'Education', 'Shows', 'Entertainment',
#        'https://us.youtubers.me/global/all/top-1000-most_subscribed-youtube-channels',
#        'Gaming', 'People & Blogs', 'Sports', 'Howto & Style',
#        'News & Politics', 'Comedy', 'Trailers', 'Nonprofits & Activism',
#        'Science & Technology', 'Movies', 'Pets & Animals',
#        'Autos & Vehicles', 'Travel & Events'], dtype=object)

# %%
df.groupby('Category')['Category'].count()
# Out:
# Category
# Autos & Vehicles                                                                  1
# Comedy                                                                           68
# Education                                                                        45
# Entertainment                                                                   238
# Film & Animation                                                                 50
# Gaming                                                                           94
# Howto & Style                                                                    43
# Movies                                                                            2
# Music                                                                           217
# News & Politics                                                                  27
# Nonprofits & Activism                                                             2
# People & Blogs                                                                  132
# Pets & Animals                                                                    6
# Science & Technology                                                             18
# Shows                                                                            14
# Sports                                                                           10
# Trailers                                                                          2
# Travel & Events                                                                   1
# https://us.youtubers.me/global/all/top-1000-most_subscribed-youtube-channels     30
# Name: Category, dtype: int64

# %% [markdown]
# *Found 30 rows that are unknown category as an URL. I will remove that unknown category*

# %%
df = df[df["Category"] != "https://us.youtubers.me/global/all/top-1000-most_subscribed-youtube-channels"]
df.Category.unique()
# Out:
# array(['Music', 'Film & Animation', 'Education', 'Shows', 'Entertainment',
#        'Gaming', 'People & Blogs', 'Sports', 'Howto & Style',
#        'News & Politics', 'Comedy', 'Trailers', 'Nonprofits & Activism',
#        'Science & Technology', 'Movies', 'Pets & Animals',
#        'Autos & Vehicles', 'Travel & Events'], dtype=object)

# %%
df.shape
# Out:
# (970, 6)

# %% [markdown]
# *30 rows have been removed*

# %%
df.describe()
# Out:
#         Subscribers   Video Views    Video Count      Started
# count  9.700000e+02  9.700000e+02     970.000000   970.000000
# mean   2.143093e+07  1.011864e+10    9693.675258  2012.470103
# std    1.629649e+07  1.313615e+10   32646.007496     4.084964
# min    1.140000e+07  0.000000e+00       0.000000  1970.000000
# 25%    1.340000e+07  3.957143e+09     377.500000  2010.000000
# 50%    1.660000e+07  6.759344e+09     932.500000  2013.000000
# 75%    2.310000e+07  1.242537e+10    3377.750000  2015.000000
# max    2.340000e+08  2.129003e+11  342802.000000  2021.000000

# %% [markdown]
# **4. Data Visualization**

# %% [markdown]
# **Number of Youtube Channel By Category**

# %%
import plotly.express as px

# %%
categories=df['Category'].value_counts()
fig=px.pie(values=categories.values,
          names=categories.index,
          color_discrete_sequence=px.colors.sequential.RdBu,
          title="Number of Youtube Channel By Category", template='presentation'
          )
fig.update_traces(textposition='inside',
                  textfont_size=11,
                  textinfo='percent+label')
fig.show();
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="5fb486e8-d7a6-4a51-8994-a27a6350abdc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5fb486e8-d7a6-4a51-8994-a27a6350abdc")) {                    Plotly.newPlot(                        "5fb486e8-d7a6-4a51-8994-a27a6350abdc",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}<br>value=%{value}<extra></extra>","labels":["Entertainment","Music","People & Blogs","Gaming","Comedy","Film & Animation","Education","Howto & Style","News & Politics","Science & Technology","Shows","Sports","Pets & Animals","Trailers","Nonprofits & Activism","Movies","Autos & Vehicles","Travel & Events"],"legendgroup":"","name":"","showlegend":true,"values":[238,217,132,94,68,50,45,43,27,18,14,10,6,2,2,2,1,1],"type":"pie","textfont":{"size":11},"textinfo":"percent+label","textposition":"inside"}],                        {"template":{"data":{"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"width":3},"marker":{"size":9},"type":"scatter3d"}],"scattergeo":[{"line":{"width":3},"marker":{"size":9},"type":"scattergeo"}],"scattergl":[{"line":{"width":3},"marker":{"size":9},"type":"scattergl"}],"scatterpolargl":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolargl"}],"scatterpolar":[{"line":{"width":3},"marker":{"size":9},"type":"scatterpolar"}],"scatter":[{"line":{"width":3},"marker":{"size":9},"type":"scatter"}],"scatterternary":[{"line":{"width":3},"marker":{"size":9},"type":"scatterternary"}],"table":[{"cells":{"height":30},"header":{"height":36},"type":"table"}]},"layout":{"font":{"size":18},"xaxis":{"title":{"standoff":15}},"yaxis":{"title":{"standoff":15}}}},"legend":{"tracegroupgap":0},"title":{"text":"Number of Youtube Channel By Category"},"piecolorway":["rgb(103,0,31)","rgb(178,24,43)","rgb(214,96,77)","rgb(244,165,130)","rgb(253,219,199)","rgb(247,247,247)","rgb(209,229,240)","rgb(146,197,222)","rgb(67,147,195)","rgb(33,102,172)","rgb(5,48,97)"]},                        {"responsive": true}                    ).then(function(){
#
# var gd = document.getElementById('5fb486e8-d7a6-4a51-8994-a27a6350abdc');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })                };                            </script>        </div>
# </body>
# </html>

# %% [markdown]
# *Entertainment, Music and People & Blogs are top 3 of category proportion*

# %% [markdown]
# **Video views and Subscribers By Categories**

# %%
fig = px.scatter(df, x="Subscribers", y="Video Views",
                 size="Video Views", color="Category",
                 log_x=True, size_max=50,
                 title="Video views and Subscribers By Categories",
                 marginal_y='rug')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="98268fa6-3162-46dd-819d-cd0e96ae7100" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Trend in the YouTube Channels Created Each Year',size=30, color='maroon');

# %% [markdown]
# *The maximum number of the Youtube Channels started in 2015 and then decreases since 2015.*

# %% [markdown]
# **Top 10 Music Youtube Channels with The Most Video Count**

# %%
df_music = df[df.Category == 'Music']
df_music.head()
# Out:
#       Youtube Channel  Subscribers   Video Views  Video Count Category  \
# 0            T-Series    234000000  212900271553        18515    Music
# 12  Zee Music Company     91600000   53352597784         7530    Music
# 18          BANGTANTV     73100000   19240057894         2090    Music
# 19      Justin Bieber     70800000   29598652357          249    Music
# 20        HYBE LABELS     69600000   25947702825         1070    Music
#
#     Started
# 0      2006
# 12     2014
# 18     2012
# 19     2007
# 20     2008

# %%
new_index = df_music["Video Count"].sort_values(ascending = False).index.values
sorted_df_music = df_music.reindex(new_index)
sorted_df_music_10 = sorted_df_music[:10]

plt.figure(figsize=(15,10))

sns.barplot(sorted_df_music_10, x="Youtube Channel", y="Video Count", palette = "pastel")

plt.xticks(rotation = 90)
plt.xlabel("Youtube Channel", fontsize = 15)
plt.ylabel("Video Count", fontsize = 15)
plt.title("Top 10 Music Youtube Channels with The Most Video Count", fontsize =20)
# Out:
# Text(0.5, 1.0, 'Top 10 Music Youtube Channels with The Most Video Count')

# %% [markdown]
# *Indosiar has the most video count of Music category*

# %% [markdown]
# **Top 10 Education Youtube Channels with The Most Video View**

# %%
df_edu = df[df.Category == "Education"]
df_edu.head()
# Out:
#                                       Youtube Channel  Subscribers  \
# 2                          Cocomelon - Nursery Rhymes    152000000
# 23        Pinkfong Baby Shark - Kids' Songs & Stories     64600000
# 25              ChuChu TV Nursery Rhymes & Kids Songs     61100000
# 42  BillionSurpriseToys - English Kids Songs & Car...     49700000
# 43                                  Infobells - Hindi     48400000
#
#      Video Views  Video Count   Category  Started
# 2   149084178448          846  Education     2006
# 23   35934421688         2599  Education     2011
# 25   41904239949          531  Education     2013
# 42    8662901485          637  Education     2013
# 43   27621598218          514  Education     2014

# %%
new_index2 = df_edu["Video Views"].sort_values(ascending = False).index.values
sorted_df_edu = df_edu.reindex(new_index2)
sorted_df_edu_10 = sorted_df_edu[:10]

plt.figure(figsize=(15,10))

sns.barplot(sorted_df_edu_10, x="Youtube Channel", y="Video Views", palette = "pastel")

plt.xticks(rotation = 90)
plt.xlabel("Youtube Channel", fontsize = 15)
plt.ylabel("Video Views", fontsize = 15)
plt.title("Top 10 Education Youtube Channels with The Most Video Views", fontsize =20)
# Out:
# Text(0.5, 1.0, 'Top 10 Education Youtube Channels with The Most Video Views')

# %% [markdown]
# *Cocomelon has the most video view of Education category*

# %% [markdown]
# **Relation between Subscribers and Video Views**

# %%
sns.regplot(data=df, x='Subscribers', y='Video Views').set_title('Relation between Subscribers and Video Views')
# Out:
# Text(0.5, 1.0, 'Relation between Subscribers and Video Views')

# %% [markdown]
# **Relation between Subscribers and Video Count**

# %%
sns.regplot(data=df, x='Subscribers', y='Video Count').set_title('Relation between Subscribers and Video Count')
# Out:
# Text(0.5, 1.0, 'Relation between Subscribers and Video Count')

# %% [markdown]
# **Relation between Video Views and Video Count**

# %%
sns.regplot(data=df, x='Video Views', y='Video Count').set_title('Relation between Video Views and Video Count')
# Out:
# Text(0.5, 1.0, 'Relation between Video Views and Video Count')

# %% [markdown]
# **The heat chart depicts the correlation**

# %%
plt.figure(figsize=(20,8))
sns.set_theme('notebook')
sns.heatmap(df.corr(), annot=True, center=True);
